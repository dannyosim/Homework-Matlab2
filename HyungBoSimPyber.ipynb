# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv

# %%
ride_df=pd.read_csv("/Users/Danny/Downloads/USCLOS201805DATA1-Class-Repository-DATA-master/02-Homework/05-Matplotlib/Instructions/Pyber/raw_data/ride_data.csv")
city_df=pd.read_csv("/Users/Danny/Downloads/USCLOS201805DATA1-Class-Repository-DATA-master/02-Homework/05-Matplotlib/Instructions/Pyber/raw_data/city_data.csv")

# %%
cityinfo_df=pd.merge(ride_df, city_df, on="city")
cityinfo_df.head(30)
# Out:
#                   city                 date   fare        ride_id  \
# 0   Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1   Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2   Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3   Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4   Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
# 5   Lake Jonathanshire  2018-04-06 11:30:32  16.84  6164453571846
# 6   Lake Jonathanshire  2018-03-21 00:18:34  37.95  8353656732934
# 7   Lake Jonathanshire  2018-01-28 00:07:00   5.67  9756573174778
# 8   Lake Jonathanshire  2018-01-24 12:24:22  34.65  3319117904437
# 9   Lake Jonathanshire  2018-03-24 16:27:49  14.94  1670908453476
# 10  Lake Jonathanshire  2018-04-11 22:10:30  12.81  5999870428814
# 11  Lake Jonathanshire  2018-01-23 21:43:16  21.11  7711472105447
# 12  Lake Jonathanshire  2018-01-29 00:19:07  41.05  6649692036139
# ...

# %%
grouped_city_df = cityinfo_df.groupby(['type'])
print (grouped_city_df)
grouped_city_df.head()
# Out:
# ...
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1     Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2     Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3     Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4     Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
# 1625       Barronchester  2018-01-27 03:08:01  27.79  6653622887913
# 1626       Barronchester  2018-05-05 04:03:11  30.38  2281522828169
# 1627       Barronchester  2018-04-25 19:11:43  36.13  2660177707065
# 1628       Barronchester  2018-03-31 06:05:30  44.24  1252888806772
# 1629       Barronchester  2018-03-02 23:36:58  36.49  4031573980778
# 2250      Randallchester  2018-04-13 11:13:31  43.22  1076079536213
# 2251      Randallchester  2018-02-19 03:52:47  58.55  8004803682564
# 2252      Randallchester  2018-02-11 05:42:29  25.78  9010611749008
# ...

# %%
fare_total=grouped_city_df["fare"].sum()

# %%
fare_total.head()
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
labels = ["Rural", "Suburban", "Urban"]


sizes = [4327.93, 19356.33, 39854.38]


colors = ["red", "orange", "lightcoral"]


explode = (0.1, 0, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True)

plt.title("Total Fares by City Type")
# Out:
# Text(0.5,1,'Total Fares by City Type')

# %%
grouped_city_df = cityinfo_df.groupby(['type'])
fares_per_city_df = grouped_city_df['type'].count()
print (fares_per_city_df)
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: type, dtype: int64

# %%
labels = ["Rural", "Suburban", "Urban"]


sizes = [125, 625, 1625]


colors = ["red", "orange", "lightcoral"]


explode = (0.1, 0, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True)

plt.title("Total Rides by City Type")
# Out:
# Text(0.5,1,'Total Rides by City Type')

# %%
grouped_drivers_df= city_df.groupby(["type"])
number_of_drivers = grouped_drivers_df["driver_count"].sum()
number_of_drivers
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
labels = ["Rural", "Suburban", "Urban"]


sizes = [78, 490, 2405]


colors = ["red", "orange", "lightcoral"]


explode = (0.1, 0, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True)

plt.title("% of Total Drivers by City Type")
# Out:
# Text(0.5,1,'Total Rides by City Type')
